# %% [markdown]
# # Procesamiento de Datos a Gran Escala - Taller 01-Bono
# **Universidad:** Pontificia Universidad Javeriana
# **Autor:** Andrés Felipe Díaz Torres
# **Fecha:** 12 de agosto de 2026
# **Docente:** John Corredor
# **Objetivo:** Aplicar de manera integrada los conceptos vistos en el taller (cadenas, tuplas, listas, conjuntos, diccionarios, condiciones, bucles, funciones y clases) en un ejercicio práctico complementario.

# %% [markdown]
# ## CALENTAMIENTO:

# %% [markdown]
# #### MENOR DE DOS PARES: Escriba una función que devuelva el menor de dos números dados *si* ambos números son pares, pero devuelva el mayor si uno o ambos números son impares
#     lesser_of_two_evens(2,4) --> 2
#     lesser_of_two_evens(2,5) --> 5

# %%
# Función que retorna el menor si ambos son pares, o el mayor si alguno es impar.
def lesser_of_two_evens(a,b):
    if a % 2 == 0 and b % 2 == 0:
        return min(a, b)
    else:
        return max(a, b)

# %%
# Caso ambos pares: 2 y 4 -> retorna 2
lesser_of_two_evens(2,4)
# Out:
# 2

# %%
# Caso par/impar: 2 y 5 -> retorna 5
lesser_of_two_evens(2,5)
# Out:
# 5

# %% [markdown]
# #### GALLETAS DE ANIMALES: Escribir una función que toma una cadena de dos palabras y devuelve True si ambas palabras comienzan con la misma letra
#     animal_crackers('Ciudad Calor') --> True
#     animal_crackers('Lugar Frio') --> False

# %%
# Revisa si ambas inicial con la misma letra
def animal_crackers(text):
    words = text.lower().split()
    return words[0][0] == words[1][0]

# %%
# Caso verdadero
animal_crackers('Ciudad Calor')
# Out:
# True

# %%
# caso falso
animal_crackers('Lugar Frio')
# Out:
# False

# %% [markdown]
# #### HACE VEINTE: dados dos enteros, devuelve True si la suma de los enteros es 20 o si uno de los enteros es 20. De lo contrario, devuelve False
#
#     makes_twenty(20,10) --> True
#     makes_twenty(12,8) --> True
#     makes_twenty(2,3) --> False

# %%
# Si la suma o alguno de los dos es 20
def makes_twenty(n1,n2):
    return (n1 == 20) or (n2 == 20) or (n1 + n2 == 20)

# %%
# Uno de los dos es 20
makes_twenty(20,10)
# Out:
# True

# %%
# Ninguno lo es y la suma no da 20
makes_twenty(2,3)
# Out:
# False

# %%
# La suma de los dos da 20
makes_twenty(12,8)
# Out:
# True

# %% [markdown]
# # Nivel 1

# %% [markdown]
# #### MAYÚSCULAS: Escribir una función que haga mayúscula la primera y cuarta letra de una cadena de texto
#
#     old_macdonald('macdonald') --> MacDonald
#
# Note: `'macdonald'.capitalize()` returns `'Macdonald'`

# %%
# Capitalizar la primera posición (0) y la cuarta (3)
def old_macdonald(name):
    if len(name) >= 4:
        return name[:3].capitalize() + name[3:].capitalize()
    return name.capitalize()

# %%
# el ejemplo que nos daban
old_macdonald('macdonald')
# Out:
# 'MacDonald'

# %% [markdown]
# #### REVERSA: Dada una oración, retornar la misma oración pero en reversa
#
#     master_yoda('I am home') --> 'home am I'
#     master_yoda('We are ready') --> 'ready are We'
#
# Note: Revisar método .join()
#
#     >>> "--".join(['a','b','c'])
#     >>> 'a--b--c'
#
# Resultado de .join():
#
#     >>> " ".join(['Hello','world'])
#     >>> "Hello world"

# %%
# Función que invierte el orden de las palabras en una oración.
def master_yoda(text):
    return " ".join(text.split()[::-1])

# %%
# Revisión: 'I am home' -> 'home am I'
master_yoda('I am home')
# Out:
# 'home am I'

# %%
# Revisión: 'We are ready' -> 'ready are We'
master_yoda('We are ready')
# Out:
# 'ready are We'

# %% [markdown]
# # Nivel 2

# %% [markdown]
# #### PROBLEMA 33:
#
# Dada una lista de enteros, retornar True si el arreglo tinene un  3  seguido por un  3 .
#
#     has_33([1, 3, 3]) → True
#     has_33([1, 3, 1, 3]) → False
#     has_33([3, 1, 3]) → False

# %%
# Función que detecta si existe un número 3 seguido inmediatamente de otro 3.
def has_33(nums):
    for i in range(len(nums) - 1):
        if nums[i] == 3 and nums[i+1] == 3:
            return True
    return False

# %%
# Caso 3 seguido de un 3
has_33([1, 3, 3])
# Out:
# True

# %%
# Caso 3 separados
has_33([1, 3, 1, 3])
# Out:
# False

# %%
# Caso 3 al inicio y al final
has_33([3, 1, 3])
# Out:
# False

# %% [markdown]
# #### REPLICADOR: Dada una cadena, devuelve una cadena donde por cada carácter en el original hay tres caracteres REPETIDOS
#     paper_doll('Hello') --> 'HHHeeellllllooo'
#     paper_doll('Mississippi') --> 'MMMiiissssssiiippppppiii'

# %%
# Función que repite 3 veces cada caracter de la cadena recibida.
def paper_doll(text):
    return "".join([char * 3 for char in text])

# %%
# Check: 'Hello' -> 'HHHeeellllllooo'
paper_doll('Hello')
# Out:
# 'HHHeeellllllooo'

# %%
# Check: 'Mississippi' -> 'MMMiiissssssiiippppppiii'
paper_doll('Mississippi')
# Out:
# 'MMMiiissssssiiissssssiiippppppiii'

# %% [markdown]
# #### BLACKJACK: Dados tres enteros entre 1 y 11, si su suma es menor o igual a 21, devuelve su suma. Si su suma excede 21 *y* hay un once, reduce la suma total en 10. Finalmente, si la suma (incluso después del ajuste) excede 21, devuelve 'BUST'
#     blackjack(5,6,7) --> 18
#     blackjack(9,9,9) --> 'BUST'
#     blackjack(9,9,11) --> 19

# %%
# Función de Blackjack
def blackjack(a,b,c):
    total = sum([a, b, c])
    if total <= 21:
        return total
    elif total > 21 and 11 in [a, b, c]:
        total -= 10
        if total <= 21:
            return total
        else:
            return 'BUST'
    else:
        return 'BUST'

# %%
# Caso suma <18 sin as
blackjack(5,6,7)
# Out:
# 18

# %%
# Caso perdedor
blackjack(9,9,9)
# Out:
# 'BUST'

# %%
# Caso con 11
blackjack(9,9,11)
# Out:
# 19

# %% [markdown]
# ## Suerte!
